# %% [markdown]
# <a href="https://colab.research.google.com/github/qwykeblu/AI-Spam-detection/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !pip install opendatasets
# !pip install pandas

# %%
import opendatasets as od
import pandas as pd

od.download(
    "https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: qwykeblu
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 211k/211k [00:00<00:00, 535kB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from IPython.display import display
import pandas as pd

spam_data = pd.read_csv("/content/sms-spam-collection-dataset/spam.csv", encoding="ISO-8859-1")

display(spam_data)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %% [markdown]
# checking the duplicates

# %%
import matplotlib.pyplot as plt


rows_count_b = len(spam_data.index)
copy_spam_data=spam_data.copy()
copy_spam_data.drop_duplicates()
rows_count_a=len(copy_spam_data.index)


check_duplicates = lambda x,y : f'No duplicates' if(x == y) else None
print(check_duplicates(rows_count_b, rows_count_a))
# Out:
# No duplicates
